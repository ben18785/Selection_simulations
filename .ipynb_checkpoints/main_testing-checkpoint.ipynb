# %%
from Selection import Bentley
from Selection import FrequencyDependent
import pandas
from scipy.stats import logistic
from joblib import Parallel, delayed
import multiprocessing
import random
import numpy as np
import pandas
import collections

# %% [markdown]
# # Neutral

# %% [markdown]
# lPops = FrequencyDependent.runAllFrequency(1000, 250, 0.004, 0, 250)
# aDF = Bentley.time_series(lPops)
# pandas.DataFrame(aDF).to_csv("time_series_neutral.csv", sep=',')

# %% [markdown]
# # Positive

# %%
lPops = FrequencyDependent.runAllFrequency(1000, 250, 0.004, 0.5, 250)
aDF = Bentley.time_series(lPops)
pandas.DataFrame(aDF).to_csv("time_series_positive.csv", sep=',')

# %% [markdown]
# # Negative

# %%
lPops = FrequencyDependent.runAllFrequency(1000, 250, 0.004, -0.5, 250)
aDF = Bentley.time_series(lPops)
pandas.DataFrame(aDF).to_csv("time_series_negative.csv", sep=',')

# %%
aDF = Bentley.time_series(lPops)
aDF = pandas.DataFrame(aDF)
aDF.columns = ["generation", "variant", "count"]

# %%
aDF
# Out:
#        generation  variant  count
# 0             1.0      2.0    1.0
# 1             1.0      5.0    4.0
# 2             1.0      8.0    1.0
# 3             1.0     10.0    2.0
# 4             1.0     12.0    1.0
# 5             1.0     14.0    2.0
# 6             1.0     15.0    1.0
# 7             1.0     16.0    2.0
# 8             1.0     17.0    1.0
# 9             1.0     21.0    1.0
# 10            1.0     23.0    1.0
# 11            1.0     24.0    1.0
# 12            1.0     26.0    1.0
# 13            1.0     27.0    1.0
# 14            1.0     29.0    3.0
# 15            1.0     32.0    4.0
# 16            1.0     33.0    2.0
# 17            1.0     34.0    3.0
# 18            1.0     35.0    3.0
# 19            1.0     38.0    3.0
# 20            1.0     41.0    1.0
# 21            1.0     42.0    1.0
# 22            1.0     44.0    1.0
# 23            1.0     46.0    1.0
# 24            1.0     47.0    1.0
# 25            1.0     48.0    3.0
# 26            1.0     49.0    3.0
# 27            1.0     50.0    1.0
# 28            1.0     53.0    1.0
# 29            1.0     55.0    3.0
# ...           ...      ...    ...
# 17812       999.0   1003.0   18.0
# 17813       999.0   1043.0    5.0
# 17814       999.0   1095.0    4.0
# 17815       999.0   1123.0   48.0
# 17816       999.0   1140.0    7.0
# 17817       999.0   1176.0   10.0
# 17818       999.0   1177.0    1.0
# 17819       999.0   1179.0   20.0
# 17820       999.0   1182.0    2.0
# 17821       999.0   1183.0   36.0
# 17822       999.0   1185.0   19.0
# 17823       999.0   1186.0   16.0
# 17824       999.0   1194.0   11.0
# 17825       999.0   1213.0    1.0
# 17826       999.0   1214.0    3.0
# 17827      1000.0    811.0    9.0
# 17828      1000.0    924.0   31.0
# 17829      1000.0   1003.0   20.0
# 17830      1000.0   1043.0    2.0
# 17831      1000.0   1095.0    2.0
# 17832      1000.0   1123.0   49.0
# 17833      1000.0   1140.0   10.0
# 17834      1000.0   1176.0   14.0
# 17835      1000.0   1179.0   18.0
# 17836      1000.0   1182.0    4.0
# 17837      1000.0   1183.0   34.0
# 17838      1000.0   1185.0   24.0
# 17839      1000.0   1186.0   19.0
# 17840      1000.0   1194.0   10.0
# 17841      1000.0   1214.0    4.0
#
# [17842 rows x 3 columns]
